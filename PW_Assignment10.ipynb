# %% [markdown]
# ### **1. What is a parameter?**
#
# A parameter is a value that a model learns during training (e.g., weights, bias).
#
# ---
#
# ### **2. What is correlation?**
#
# Correlation measures the strength and direction of the relationship between two variables.
#
# ---
#
# ### **3. What does negative correlation mean?**
#
# Negative correlation means when one variable increases, the other decreases.
#
# ---
#
# ### **4. Define Machine Learning. What are the main components in Machine Learning?**
#
# Machine Learning is a method where models learn from data to make predictions.
# **Main components:** Data, Features, Model, Training Algorithm, Evaluation.
#
# ---
#
# ### **5. How does loss value help in determining whether the model is good or not?**
#
# Lower loss value means better predictions; high loss means poor model performance.
#
# ---
#
# ### **6. What are continuous and categorical variables?**
#
# * **Continuous:** Numerical values (age, salary).
# * **Categorical:** Labels/categories (gender, color).
#
# ---
#
# ### **7. How do we handle categorical variables in Machine Learning? What are the common techniques?**
#
# Common techniques:
#
# * Label Encoding
# * One-Hot Encoding
# * Ordinal Encoding
#
# ---
#
# ### **8. What do you mean by training and testing a dataset?**
#
# * **Training set:** Used to train the model.
# * **Testing set:** Used to evaluate the trained model.
#
# ---
#
# ### **9. What is sklearn.preprocessing?**
#
# A scikit-learn module used for data preprocessing like scaling and encoding.
#
# ---
#
# ### **10. What is a Test set?**
#
# Data used only to test the model after training.
#
# ---
#
# ### **11. How do we split data for model fitting (training and testing) in Python?**
#
# ```python
# from sklearn.model_selection import train_test_split
# X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)
# ```
#
# ---
#
# ### **12. How do you approach a Machine Learning problem?**
#
# Steps:
#
# 1. Define problem
# 2. Collect data
# 3. Clean/preprocess data
# 4. Perform EDA
# 5. Split data
# 6. Train model
# 7. Evaluate
# 8. Deploy
#
# ---
#
# ### **13. Why do we have to perform EDA before fitting a model to the data?**
#
# EDA helps understand data distribution, outliers, missing values, and relationships, improving model performance.
#
# ---
#
# ### **14. What is correlation?**
#
# (Already defined but included as it appears again)
# Correlation measures how two variables move together.
#
# ---
#
# ### **15. What does negative correlation mean?**
#
# When one value rises, the other decreases.
#
# ---
#
# ### **16. How can you find correlation between variables in Python?**
#
# Using Pandas:
#
# ```python
# df.corr()
# ```
#
# ---
#
# ### **17. What is causation? Explain difference between correlation and causation with an example.**
#
# Causation means one variable directly affects another.
# Correlation means variables move similarly but do not cause each other.
# **Example:** More ice-cream sales ↔ more drowning cases (correlation, not causation).
#
# ---
#
# ### **18. What is an Optimizer? What are different types? Explain each with an example.**
#
# Optimizers update model parameters to reduce loss.
# Types:
#
# * **SGD:** Updates weights using gradients.
# * **Adam:** Adaptive learning rate + momentum.
# * **RMSProp:** Uses moving average of gradients.
#
# ---
#
# ### **19. What is sklearn.linear_model?**
#
# A scikit-learn module containing linear models like Linear Regression and Logistic Regression.
#
# ---
#
# ### **20. What does model.fit() do? What arguments must be given?**
#
# `fit()` trains the model.
# Arguments:
#
# * X (features)
# * y (labels)
#
# ---
#
# ### **21. What does model.predict() do? What arguments must be given?**
#
# `predict()` gives predictions for new data.
# Arguments:
#
# * X_test (unseen features)
#
# ---
#
# ### **22. What are continuous and categorical variables?**
#
# (Repeat question)
# Continuous → numerical
# Categorical → non-numerical labels
#
# ---
#
# ### **23. What is feature scaling? How does it help in Machine Learning?**
#
# Feature scaling normalizes data into a standard range.
# It helps algorithms converge faster and improves performance.
#
# ---
#
# ### **24. How do we perform scaling in Python?**
#
# ```python
# from sklearn.preprocessing import StandardScaler
# scaler = StandardScaler()
# X_scaled = scaler.fit_transform(X)
# ```
#
# ---
#
# ### **25. Explain data encoding.**
#
# Data encoding converts categorical data into numerical form.
# Types: Label Encoding, One-Hot Encoding, Ordinal Encoding.
#
# ---
